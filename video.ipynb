# %%
import cv2
import matplotlib.pyplot as plt

# %%
vid=cv2.VideoCapture('images/robots.mp4')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\rajesh'

# %%
ret,frame=vid.read()

# %%
frame.shape
# Out:
# (640, 640, 3)

# %%
cv2.imshow('Frame',frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
width=int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
hight=int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
length=

# %% [markdown]
# ##

# %%
vid=cv2.VideoCapture('images/robots.mp4')
while True:
    
    ret,frame=vid.read()
    if not ret:
        break
    cv2.imshow('video',frame)
    if cv2.waitKey(5)==ord('q'):
            break


cv2.destroyAllWindows()

# %%
vid=cv2.VideoCapture('images/robots.mp4')
success,frame=vid.read()
count=1
while success:
     cv2.imwrite(f'video_frames/{count}.jpg',frame)
     success,frame=vid.read()
     count += 1

# %%
vid=cv2.VideoCapture('images/robots.mp4')
success,frame=vid.read()
count=1
while success:
     cv2.imwrite(f'video3july/{count}.jpg',frame)
     success,frame=vid.read()
     count += 1

# %%
img200=plt.imread('video_frames/100.jpg')
plt.imshow(img200)

# %%
timestamp='00:00:43'

# %%
timestamp.split()
# Out:
# ['00:00:43']

# %%
timestamp='00:00:43.00'
hours,minutes,seconds=[float(i)for i in timestamp.split(':')]
print(hours,minutes,seconds)
# Out:
# 0.0 0.0 43.0

# %%
#get number of frames up to timestamp
trigger_frame=hours*3600*fps+minutes*60*fps+seconds*fps
print(frames,trigger_frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 #get number of frames up to timestamp
# ----> 2 trigger_frame=hours*3600*fps+minutes*60*fps+seconds*fps
#       3 print(frames,trigger_frame)
#
# NameError: name 'fps' is not defined

# %%
#go to frame select by timestamp
vid.set(1,trigger_frame)
success,frame=vid.read()
#save the frame in to an image file
if success:
     cv2.imwrite('screen.jpg',frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 #go to frame select by timestamp
# ----> 2 vid.set(1,trigger_frame)
#       3 success,frame=vid.read()
#       4 #save the frame in to an image file
#
# NameError: name 'trigger_frame' is not defined

# %%
cap=cv2.VideoCapture(0)

# %%
cap.isopen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 cap.isopen
#
# AttributeError: 'cv2.VideoCapture' object has no attribute 'isopen'
